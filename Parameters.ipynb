# %%
def greet_user(first_name, last_name):
    print(f'Hi {first_name}!')
    print('Welcome aboard')
print("Start")
greet_user("John")
greet_user("Mary")
print("Finish")
# Out:
# Start
# Hi John!
# Welcome aboard
# Hi Mary!
# Welcome aboard
# Finish
