# %%
# Printing a string using a course variable
course = "Python's Course for Beginners"
print(course)
# Out:
# Python's Course for Beginners

# %%
# Include a double quote within the string
course_two = 'Python for "Beginners"'
print(course_two)
# Out:
# Python for "Beginners"

# %%
email = '''
Hi John,

Here is our first email to you.

Thank you,
The support team

'''
print(email)
# Out:
# Hi John,
#
# Here is our first email to you.
#
# Thank you,
# The support team

# %%
course_three = 'Python for Beginners'
print(course_three[0])
# Out:
# P

# %%
print(course_three[-1])
# Out:
# s

# %%
print(course_three[-2])
# Out:
# r

# %%
print(course_three[0:3])
# Out:
# Pyt

# %%
print(course_three[0:])
# Out:
# Python for Beginners

# %%
print(course_three[1:])
# Out:
# ython for Beginners

# %%
print(course_three[:5])
# Out:
# Pytho

# %%
another = course_three[:]
print(another)
# Out:
# Python for Beginners

# %%
name = 'Jennifer'
print(name[1:-1])
# Out:
# ennife

# %%
first = 'John'
last = 'Smith'
message = first + ' [' + last + '] is a coder'
print(message)
# Out:
# John [Smith] is a coder

# %%
# Formatted String version of message 
msg = f'{first} [{last}] is a coder'
print(msg)
# Out:
# John [Smith] is a coder

# %%
course_four = 'Python for Beginners'
print(len(course_four)) # find the length of the course string
# Out:
# 20

# %%
# Using the uppercase method
print(course_four.upper())
# Using the lowercase method
print(course_four.lower())
# Shows course_four variable is still unmodified
print(course_four)
# Out:
# PYTHON FOR BEGINNERS
# python for beginners
# Python for Beginners

# %%
# String method finds the index of P
course_four.find('P')
# Out:
# 0

# %%
print(course_four.find('Beginners'))
# Out:
# 11

# %%
# String method replaces the word Beginners with Absolute Beginners
print(course_four.replace('Beginners', 'Absolute Beginners'))
# Out:
# Python for Absolute Beginners

# %%
print(course_four.replace('P', 'J'))
# Out:
# Jython for Beginners

# %%
print(course_four.find('O'))
# Out:
# -1

# %%
print(course_four.find('Beginners'))
# Out:
# 11

# %%
print(course_four.replace('beginners', 'Absolute Beginners'))
# Out:
# Python for Beginners

# %%
'Python' in course_four
# Out:
# True

# %%
print('python' in course_four)
# Out:
# False
